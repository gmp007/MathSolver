# %%
# !pip install mercury
# !pip install sympy
# Out:
# Collecting mercury
#   Downloading mercury-2.4.3.tar.gz (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 26.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting django==4.2.7 (from mercury)
#   Downloading Django-4.2.7-py3-none-any.whl.metadata (4.1 kB)
# Collecting djangorestframework==3.14.0 (from mercury)
#   Downloading djangorestframework-3.14.0-py3-none-any.whl.metadata (10 kB)
# Collecting django-filter==21.1 (from mercury)
#   Downloading django_filter-21.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting markdown==3.3.6 (from mercury)
#   Downloading Markdown-3.3.6-py3-none-any.whl.metadata (4.6 kB)
# Collecting celery>=5.1.2 (from mercury)
#   Downloading celery-5.4.0-py3-none-any.whl.metadata (21 kB)
# Collecting sqlalchemy==1.4.27 (from mercury)
#   Downloading SQLAlchemy-1.4.27-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10.0 kB)
# Collecting gevent (from mercury)
#   Downloading gevent-24.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting nbconvert>=7.8.0 (from mercury)
#   Downloading nbconvert-7.16.4-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from mercury) (0.2.0)
# Collecting django-cors-headers==3.10.1 (from mercury)
#   Downloading django_cors_headers-3.10.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: ipython>=7.30.1 in /usr/local/lib/python3.10/dist-packages (from mercury) (7.34.0)
# Collecting ipykernel>=6.6.0 (from mercury)
#   Downloading ipykernel-6.29.5-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from mercury) (5.9.5)
# Collecting whitenoise>=5.3.0 (from mercury)
#   Downloading whitenoise-6.7.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting python-dotenv>=0.19.2 (from mercury)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting django-drf-filepond==0.4.1 (from mercury)
#   Downloading django_drf_filepond-0.4.1-py2.py3-none-any.whl.metadata (21 kB)
# Collecting croniter>=1.3.5 (from mercury)
#   Downloading croniter-3.0.4-py2.py3-none-any.whl.metadata (29 kB)
# Collecting pyppeteer==1.0.2 (from mercury)
#   Downloading pyppeteer-1.0.2-py3-none-any.whl.metadata (6.9 kB)
# Collecting channels>=4.0.0 (from channels[daphne]>=4.0.0->mercury)
#   Downloading channels-4.1.0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: websocket-client>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from mercury) (1.8.0)
# Collecting execnb (from mercury)
#   Downloading execnb-0.1.6-py3-none-any.whl.metadata (3.2 kB)
# Collecting ipywidgets==8.0.3 (from mercury)
#   Downloading ipywidgets-8.0.3-py3-none-any.whl.metadata (2.3 kB)
# Collecting dj-rest-auth==3.0.0 (from dj-rest-auth[with_social]==3.0.0->mercury)
#   Downloading dj-rest-auth-3.0.0.tar.gz (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.2/100.2 kB 7.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting boto3==1.26.83 (from mercury)
#   Downloading boto3-1.26.83-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.10/dist-packages (from mercury) (43.0.3)
# Requirement already satisfied: pyopenssl>=23.1.1 in /usr/local/lib/python3.10/dist-packages (from mercury) (24.2.1)
# Requirement already satisfied: bleach>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from mercury) (6.1.0)
# Collecting itables>=2.0.0 (from mercury)
#   Downloading itables-2.2.2-py3-none-any.whl.metadata (8.3 kB)
# Collecting botocore<1.30.0,>=1.29.83 (from boto3==1.26.83->mercury)
#   Downloading botocore-1.29.165-py3-none-any.whl.metadata (5.9 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3==1.26.83->mercury)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.7.0,>=0.6.0 (from boto3==1.26.83->mercury)
#   Downloading s3transfer-0.6.2-py3-none-any.whl.metadata (1.8 kB)
# Collecting django-allauth<0.53.0,>=0.40.0 (from dj-rest-auth[with_social]==3.0.0->mercury)
#   Downloading django-allauth-0.52.0.tar.gz (728 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 728.3/728.3 kB 33.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting asgiref<4,>=3.6.0 (from django==4.2.7->mercury)
#   Downloading asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: sqlparse>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from django==4.2.7->mercury) (0.5.1)
# Requirement already satisfied: requests>=2.20.1 in /usr/local/lib/python3.10/dist-packages (from django-drf-filepond==0.4.1->mercury) (2.32.3)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from django-drf-filepond==0.4.1->mercury) (1.16.0)
# Collecting shortuuid>=0.5.0 (from django-drf-filepond==0.4.1->mercury)
#   Downloading shortuuid-1.0.13-py3-none-any.whl.metadata (5.8 kB)
# Collecting django-storages>=1.9.1 (from django-drf-filepond==0.4.1->mercury)
#   Downloading django_storages-1.14.4-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from djangorestframework==3.14.0->mercury) (2024.2)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets==8.0.3->mercury) (5.7.1)
# Collecting widgetsnbextension~=4.0 (from ipywidgets==8.0.3->mercury)
#   Downloading widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets==8.0.3->mercury) (3.0.13)
# Collecting appdirs<2.0.0,>=1.4.3 (from pyppeteer==1.0.2->mercury)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: certifi>=2021 in /usr/local/lib/python3.10/dist-packages (from pyppeteer==1.0.2->mercury) (2024.8.30)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.10/dist-packages (from pyppeteer==1.0.2->mercury) (8.5.0)
# Collecting pyee<9.0.0,>=8.1.0 (from pyppeteer==1.0.2->mercury)
#   Downloading pyee-8.2.2-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from pyppeteer==1.0.2->mercury) (4.66.5)
# Collecting urllib3<2.0.0,>=1.25.8 (from pyppeteer==1.0.2->mercury)
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 3.5 MB/s eta 0:00:00
# Collecting websockets<11.0,>=10.0 (from pyppeteer==1.0.2->mercury)
#   Downloading websockets-10.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy==1.4.27->mercury) (3.1.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach>=6.0.0->mercury) (0.5.1)
# Collecting billiard<5.0,>=4.2.0 (from celery>=5.1.2->mercury)
#   Downloading billiard-4.2.1-py3-none-any.whl.metadata (4.4 kB)
# Collecting kombu<6.0,>=5.3.4 (from celery>=5.1.2->mercury)
#   Downloading kombu-5.4.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting vine<6.0,>=5.1.0 (from celery>=5.1.2->mercury)
#   Downloading vine-5.1.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: click<9.0,>=8.1.2 in /usr/local/lib/python3.10/dist-packages (from celery>=5.1.2->mercury) (8.1.7)
# Collecting click-didyoumean>=0.3.0 (from celery>=5.1.2->mercury)
#   Downloading click_didyoumean-0.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting click-repl>=0.2.0 (from celery>=5.1.2->mercury)
#   Downloading click_repl-0.3.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting click-plugins>=1.1.1 (from celery>=5.1.2->mercury)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from celery>=5.1.2->mercury) (2024.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from celery>=5.1.2->mercury) (2.8.2)
# Collecting daphne>=4.0.0 (from channels[daphne]>=4.0.0->mercury)
#   Downloading daphne-4.1.2-py3-none-any.whl.metadata (6.5 kB)
# Collecting comm>=0.1.1 (from ipykernel>=6.6.0->mercury)
#   Downloading comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: debugpy>=1.6.5 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=6.6.0->mercury) (1.6.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=6.6.0->mercury) (6.1.12)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=6.6.0->mercury) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=6.6.0->mercury) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from ipykernel>=6.6.0->mercury) (1.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from ipykernel>=6.6.0->mercury) (24.1)
# Requirement already satisfied: pyzmq>=24 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=6.6.0->mercury) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=6.6.0->mercury) (6.3.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.30.1->mercury) (75.1.0)
# Collecting jedi>=0.16 (from ipython>=7.30.1->mercury)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=7.30.1->mercury) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=7.30.1->mercury) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.30.1->mercury) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=7.30.1->mercury) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=7.30.1->mercury) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.30.1->mercury) (4.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from itables>=2.0.0->mercury) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from itables>=2.0.0->mercury) (2.2.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=7.8.0->mercury) (4.12.3)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=7.8.0->mercury) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=7.8.0->mercury) (3.1.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=7.8.0->mercury) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=7.8.0->mercury) (3.0.2)
# Collecting mistune<4,>=2.0.3 (from nbconvert>=7.8.0->mercury)
#   Downloading mistune-3.0.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=7.8.0->mercury) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=7.8.0->mercury) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=7.8.0->mercury) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=7.8.0->mercury) (1.3.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography->mercury) (1.17.1)
# Requirement already satisfied: fastcore>=1.5.5 in /usr/local/lib/python3.10/dist-packages (from execnb->mercury) (1.7.19)
# Collecting zope.event (from gevent->mercury)
#   Downloading zope.event-5.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting zope.interface (from gevent->mercury)
#   Downloading zope.interface-7.1.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from asgiref<4,>=3.6.0->django==4.2.7->mercury) (4.12.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography->mercury) (2.22)
# Collecting autobahn>=22.4.2 (from daphne>=4.0.0->channels[daphne]>=4.0.0->mercury)
#   Downloading autobahn-24.4.2-py2.py3-none-any.whl.metadata (18 kB)
# Collecting twisted>=22.4 (from twisted[tls]>=22.4->daphne>=4.0.0->channels[daphne]>=4.0.0->mercury)
#   Downloading twisted-24.7.0-py3-none-any.whl.metadata (18 kB)
# Collecting python3-openid>=3.0.8 (from django-allauth<0.53.0,>=0.40.0->dj-rest-auth[with_social]==3.0.0->mercury)
#   Downloading python3_openid-3.2.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: requests-oauthlib>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from django-allauth<0.53.0,>=0.40.0->dj-rest-auth[with_social]==3.0.0->mercury) (1.3.1)
# Requirement already satisfied: pyjwt>=1.7 in /usr/local/lib/python3.10/dist-packages (from pyjwt[crypto]>=1.7->django-allauth<0.53.0,>=0.40.0->dj-rest-auth[with_social]==3.0.0->mercury) (2.9.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=1.4->pyppeteer==1.0.2->mercury) (3.20.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=7.30.1->mercury) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=6.6.0->mercury) (4.3.6)
# Collecting amqp<6.0.0,>=5.1.1 (from kombu<6.0,>=5.3.4->celery>=5.1.2->mercury)
#   Downloading amqp-5.2.0-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.7->nbconvert>=7.8.0->mercury) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.7->nbconvert>=7.8.0->mercury) (4.23.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=7.30.1->mercury) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.30.1->mercury) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20.1->django-drf-filepond==0.4.1->mercury) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20.1->django-drf-filepond==0.4.1->mercury) (3.10)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=7.8.0->mercury) (2.6)
# Collecting txaio>=21.2.1 (from autobahn>=22.4.2->daphne>=4.0.0->channels[daphne]>=4.0.0->mercury)
#   Downloading txaio-23.1.1-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting hyperlink>=21.0.0 (from autobahn>=22.4.2->daphne>=4.0.0->channels[daphne]>=4.0.0->mercury)
#   Downloading hyperlink-21.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=7.8.0->mercury) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=7.8.0->mercury) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=7.8.0->mercury) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=7.8.0->mercury) (0.20.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.3.0->django-allauth<0.53.0,>=0.40.0->dj-rest-auth[with_social]==3.0.0->mercury) (3.2.2)
# Collecting automat>=0.8.0 (from twisted>=22.4->twisted[tls]>=22.4->daphne>=4.0.0->channels[daphne]>=4.0.0->mercury)
#   Downloading Automat-24.8.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting constantly>=15.1 (from twisted>=22.4->twisted[tls]>=22.4->daphne>=4.0.0->channels[daphne]>=4.0.0->mercury)
#   Downloading constantly-23.10.4-py3-none-any.whl.metadata (1.8 kB)
# Collecting incremental>=24.7.0 (from twisted>=22.4->twisted[tls]>=22.4->daphne>=4.0.0->channels[daphne]>=4.0.0->mercury)
#   Downloading incremental-24.7.2-py3-none-any.whl.metadata (8.1 kB)
# Collecting service-identity>=18.1.0 (from twisted[tls]>=22.4->daphne>=4.0.0->channels[daphne]>=4.0.0->mercury)
#   Downloading service_identity-24.2.0-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: tomli in /usr/local/lib/python3.10/dist-packages (from incremental>=24.7.0->twisted>=22.4->twisted[tls]>=22.4->daphne>=4.0.0->channels[daphne]>=4.0.0->mercury) (2.0.2)
# Requirement already satisfied: pyasn1 in /usr/local/lib/python3.10/dist-packages (from service-identity>=18.1.0->twisted[tls]>=22.4->daphne>=4.0.0->channels[daphne]>=4.0.0->mercury) (0.6.1)
# Requirement already satisfied: pyasn1-modules in /usr/local/lib/python3.10/dist-packages (from service-identity>=18.1.0->twisted[tls]>=22.4->daphne>=4.0.0->channels[daphne]>=4.0.0->mercury) (0.4.1)
# Downloading boto3-1.26.83-py3-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.7/134.7 kB 11.2 MB/s eta 0:00:00
# Downloading Django-4.2.7-py3-none-any.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 61.6 MB/s eta 0:00:00
# Downloading django_cors_headers-3.10.1-py3-none-any.whl (12 kB)
# Downloading django_drf_filepond-0.4.1-py2.py3-none-any.whl (39 kB)
# Downloading django_filter-21.1-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 6.3 MB/s eta 0:00:00
# Downloading djangorestframework-3.14.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 41.1 MB/s eta 0:00:00
# Downloading ipywidgets-8.0.3-py3-none-any.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 10.7 MB/s eta 0:00:00
# Downloading Markdown-3.3.6-py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.8/97.8 kB 8.0 MB/s eta 0:00:00
# Downloading pyppeteer-1.0.2-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.4/83.4 kB 7.1 MB/s eta 0:00:00
# Downloading SQLAlchemy-1.4.27-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 45.7 MB/s eta 0:00:00
# Downloading celery-5.4.0-py3-none-any.whl (425 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.0/426.0 kB 19.5 MB/s eta 0:00:00
# Downloading channels-4.1.0-py3-none-any.whl (30 kB)
# Downloading croniter-3.0.4-py2.py3-none-any.whl (23 kB)
# Downloading ipykernel-6.29.5-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 kB 9.0 MB/s eta 0:00:00
# Downloading itables-2.2.2-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 45.5 MB/s eta 0:00:00
# Downloading nbconvert-7.16.4-py3-none-any.whl (257 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.4/257.4 kB 18.9 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading whitenoise-6.7.0-py3-none-any.whl (19 kB)
# Downloading execnb-0.1.6-py3-none-any.whl (14 kB)
# Downloading gevent-24.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 63.7 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Downloading billiard-4.2.1-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.9 MB/s eta 0:00:00
# Downloading botocore-1.29.165-py3-none-any.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 60.2 MB/s eta 0:00:00
# Downloading click_didyoumean-0.3.1-py3-none-any.whl (3.6 kB)
# Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Downloading click_repl-0.3.0-py3-none-any.whl (10 kB)
# Downloading comm-0.2.2-py3-none-any.whl (7.2 kB)
# Downloading daphne-4.1.2-py3-none-any.whl (30 kB)
# Downloading django_storages-1.14.4-py3-none-any.whl (31 kB)
# Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 62.0 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading kombu-5.4.2-py3-none-any.whl (201 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 kB 15.6 MB/s eta 0:00:00
# Downloading vine-5.1.0-py3-none-any.whl (9.6 kB)
# Downloading mistune-3.0.2-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.0/48.0 kB 3.8 MB/s eta 0:00:00
# Downloading pyee-8.2.2-py2.py3-none-any.whl (12 kB)
# Downloading s3transfer-0.6.2-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 7.1 MB/s eta 0:00:00
# Downloading shortuuid-1.0.13-py3-none-any.whl (10 kB)
# Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 11.9 MB/s eta 0:00:00
# Downloading websockets-10.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 9.4 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 64.1 MB/s eta 0:00:00
# Downloading zope.event-5.0-py3-none-any.whl (6.8 kB)
# Downloading zope.interface-7.1.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (254 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.2/254.2 kB 18.5 MB/s eta 0:00:00
# Downloading amqp-5.2.0-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.2 MB/s eta 0:00:00
# Downloading autobahn-24.4.2-py2.py3-none-any.whl (666 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 667.0/667.0 kB 39.5 MB/s eta 0:00:00
# Downloading python3_openid-3.2.0-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 11.2 MB/s eta 0:00:00
# Downloading twisted-24.7.0-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 69.5 MB/s eta 0:00:00
# Downloading Automat-24.8.1-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 3.2 MB/s eta 0:00:00
# Downloading constantly-23.10.4-py3-none-any.whl (13 kB)
# Downloading hyperlink-21.0.0-py2.py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 6.6 MB/s eta 0:00:00
# Downloading incremental-24.7.2-py3-none-any.whl (20 kB)
# Downloading service_identity-24.2.0-py3-none-any.whl (11 kB)
# Downloading txaio-23.1.1-py2.py3-none-any.whl (30 kB)
# Building wheels for collected packages: mercury, dj-rest-auth, django-allauth
#   Building wheel for mercury (pyproject.toml) ... done
#   Created wheel for mercury: filename=mercury-2.4.3-py3-none-any.whl size=2690608 sha256=f528e9d17fea2e5475951c84ab6e7c99f95918f4664db2431dccf65beb3b821c
#   Stored in directory: /root/.cache/pip/wheels/e5/06/48/c70891090fa742dd36c7b0f947fccb7b31739282e688edc55e
#   Building wheel for dj-rest-auth (setup.py) ... done
#   Created wheel for dj-rest-auth: filename=dj_rest_auth-3.0.0-py2.py3-none-any.whl size=155048 sha256=6aa647fb469a120118e89b8caab7efdf62a0b5cfa064179279435b7423018457
#   Stored in directory: /root/.cache/pip/wheels/f3/61/ee/f3f4df9a52508d7cfde6d16ab12614d3a72151cd19fc8174e7
#   Building wheel for django-allauth (setup.py) ... done
#   Created wheel for django-allauth: filename=django_allauth-0.52.0-py3-none-any.whl size=1063909 sha256=a6364b4da7aa25e15c4fa0c66b82416ac7135c083e52fef6761f8df9541ac4c2
#   Stored in directory: /root/.cache/pip/wheels/bc/71/64/b023cbec7198e182c9b01199b4bc958df13d4bcef14a684126
# Successfully built mercury dj-rest-auth django-allauth
# Installing collected packages: pyee, appdirs, zope.interface, zope.event, widgetsnbextension, whitenoise, websockets, vine, urllib3, txaio, sqlalchemy, shortuuid, python3-openid, python-dotenv, mistune, markdown, jmespath, jedi, incremental, hyperlink, constantly, comm, click-plugins, click-didyoumean, billiard, automat, asgiref, twisted, pyppeteer, gevent, django, croniter, click-repl, botocore, amqp, service-identity, s3transfer, kombu, itables, ipykernel, execnb, djangorestframework, django-storages, django-filter, django-cors-headers, channels, autobahn, ipywidgets, django-drf-filepond, django-allauth, dj-rest-auth, celery, boto3, daphne, nbconvert, mercury
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.10
#     Uninstalling widgetsnbextension-3.6.10:
#       Successfully uninstalled widgetsnbextension-3.6.10
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.3
#     Uninstalling urllib3-2.2.3:
#       Successfully uninstalled urllib3-2.2.3
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.36
#     Uninstalling SQLAlchemy-2.0.36:
#       Successfully uninstalled SQLAlchemy-2.0.36
#   Attempting uninstall: mistune
#     Found existing installation: mistune 0.8.4
#     Uninstalling mistune-0.8.4:
#       Successfully uninstalled mistune-0.8.4
#   Attempting uninstall: markdown
#     Found existing installation: Markdown 3.7
#     Uninstalling Markdown-3.7:
#       Successfully uninstalled Markdown-3.7
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 5.5.6
#     Uninstalling ipykernel-5.5.6:
#       Successfully uninstalled ipykernel-5.5.6
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 6.5.4
#     Uninstalling nbconvert-6.5.4:
#       Successfully uninstalled nbconvert-6.5.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipykernel==5.5.6, but you have ipykernel 6.29.5 which is incompatible.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.4.27 which is incompatible.
# Successfully installed amqp-5.2.0 appdirs-1.4.4 asgiref-3.8.1 autobahn-24.4.2 automat-24.8.1 billiard-4.2.1 boto3-1.26.83 botocore-1.29.165 celery-5.4.0 channels-4.1.0 click-didyoumean-0.3.1 click-plugins-1.1.1 click-repl-0.3.0 comm-0.2.2 constantly-23.10.4 croniter-3.0.4 daphne-4.1.2 dj-rest-auth-3.0.0 django-4.2.7 django-allauth-0.52.0 django-cors-headers-3.10.1 django-drf-filepond-0.4.1 django-filter-21.1 django-storages-1.14.4 djangorestframework-3.14.0 execnb-0.1.6 gevent-24.10.3 hyperlink-21.0.0 incremental-24.7.2 ipykernel-6.29.5 ipywidgets-8.0.3 itables-2.2.2 jedi-0.19.1 jmespath-1.0.1 kombu-5.4.2 markdown-3.3.6 mercury-2.4.3 mistune-3.0.2 nbconvert-7.16.4 pyee-8.2.2 pyppeteer-1.0.2 python-dotenv-1.0.1 python3-openid-3.2.0 s3transfer-0.6.2 service-identity-24.2.0 shortuuid-1.0.13 sqlalchemy-1.4.27 twisted-24.7.0 txaio-23.1.1 urllib3-1.26.20 vine-5.1.0 websockets-10.4 whitenoise-6.7.0 widgetsnbextension-4.0.13 zope.event-5.0 zope.interface-7.1.1
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy) (1.3.0)

# %%
import sympy as sp
import numpy as np
import scipy.optimize as opt
from scipy import integrate
import matplotlib.pyplot as plt
import re
import mercury as mr
import logging

# Set up logging
logging.basicConfig(level=logging.INFO)

# Define the text input for the user's question
question_input = mr.Text(
    label="Enter your mathematical question:",
    value="What is the derivative of sin(x)?"
)

# Helper function to determine the operation
def determine_operation(question):
    question_lower = question.lower()
    if any(keyword in question_lower for keyword in ["solve", "equation", "="]):
        return "Solve Expression"
    elif any(keyword in question_lower for keyword in ["plot", "graph", "visualize", "draw"]):
        return "Visualize Function"
    elif "integrate numerically" in question_lower:
        return "Integrate Numerically"
    elif "definite integral" in question_lower or "evaluate integral from" in question_lower:
        return "Definite Integral"
    elif "integrate" in question_lower or "antiderivative" in question_lower:
        return "Integrate Symbolically"
    elif any(keyword in question_lower for keyword in ["solve linear system", "system of equations"]):
        return "Solve Linear System"
    elif any(keyword in question_lower for keyword in ["differentiate", "derivative"]):
        return "Differentiate"
    else:
        return "Unknown"

# Helper functions to extract information
def extract_expression(question):
    match = re.search(r'solve.*?:?\s*(.*)', question, re.IGNORECASE)
    if match:
        return match.group(1)
    else:
        # Try to find an equation in the question
        match = re.search(r'(.+)=.+', question)
        if match:
            return question
    return question  # Default to returning the whole question

def extract_function(question):
    match = re.search(r'(?:function|f\(x\)|y=)\s*(.*)', question, re.IGNORECASE)
    if match:
        return match.group(1)
    else:
        # Try to extract from "plot ..." or "graph ..."
        match = re.search(r'(?:plot|graph|visualize)\s*(.*)', question, re.IGNORECASE)
        if match:
            return match.group(1)
    return None

def extract_function_to_differentiate(question):
    # Try to extract the function to differentiate
    match = re.search(r'(?:derivative of|differentiate|what is the derivative of)\s*(.*?)[\?\.]?$', question, re.IGNORECASE)
    if match:
        function_str = match.group(1).strip()
        # Remove trailing punctuation
        function_str = function_str.rstrip('.?')
        return function_str
    return None

def extract_range(question):
    # Extract numerical values for range
    matches = re.findall(r'from\s*([\d\.-]+)\s*to\s*([\d\.-]+)', question)
    if matches:
        start, end = matches[0]
        return float(start), float(end)
    else:
        # Default range
        return 0.0, 6.28

def extract_limits(question):
    matches = re.findall(r'from\s*([\d\.-]+)\s*to\s*([\d\.-]+)', question)
    if matches:
        lower, upper = matches[0]
        return float(lower), float(upper)
    else:
        # Default limits
        return 0.0, 1.0

# Helper function to safely parse expressions
def safe_parse(expression):
    try:
        allowed_symbols = {'x'}
        allowed_functions = {
            'sin': sp.sin, 'cos': sp.cos, 'tan': sp.tan, 'exp': sp.exp,
            'log': sp.log, 'sqrt': sp.sqrt, 'Abs': sp.Abs,
            'asin': sp.asin, 'acos': sp.acos, 'atan': sp.atan,
            'sinh': sp.sinh, 'cosh': sp.cosh, 'tanh': sp.tanh,
            'pi': sp.pi, 'E': sp.E, 'ln': sp.ln
        }

        # Split the expression if it contains an '=' for equations
        if '=' in expression:
            lhs, rhs = expression.split('=')
            expr = sp.Eq(sp.sympify(lhs.strip(), locals=allowed_functions),
                         sp.sympify(rhs.strip(), locals=allowed_functions))
        else:
            expr = sp.sympify(expression, locals=allowed_functions)

        symbols_in_expr = expr.free_symbols
        if not all(str(sym) in allowed_symbols for sym in symbols_in_expr):
            raise ValueError("Invalid symbols in expression.")
        return expr
    except Exception as e:
        logging.error(f"Error parsing expression '{expression}': {e}")
        raise ValueError(f"Invalid expression: {e}")

# Main logic
operation_value = determine_operation(question_input.value)

if operation_value == "Unknown":
    mr.Markdown("**Error:** Unable to determine the operation from the question.")
else:
    if operation_value == "Solve Expression":
        try:
            expression_str = extract_expression(question_input.value)
            x = sp.symbols('x')
            expr = safe_parse(expression_str)
            solutions = sp.solve(expr, x)
            steps = sp.pretty(sp.solve(expr, x, dict=True))
            result = str(solutions)
            mr.Markdown(f"**Result:** {result}")
            mr.Markdown(f"**Steps:**\n```\n{steps}\n```")
        except Exception as e:
            logging.error(f"Error in solving expression: {e}")
            mr.Markdown(f"**Error:** {e}")
    elif operation_value == "Visualize Function":
        try:
            function_str = extract_function(question_input.value)
            if not function_str:
                mr.Markdown("**Error:** Could not extract function to visualize.")
                raise ValueError("Function extraction failed.")
            x = sp.symbols('x')
            expr = safe_parse(function_str)
            func = sp.lambdify(x, expr, 'numpy')
            range_start, range_end = extract_range(question_input.value)
            x_vals = np.linspace(range_start, range_end, 400)
            y_vals = func(x_vals)

            plt.figure()
            plt.plot(x_vals, y_vals)
            plt.xlabel('x')
            plt.ylabel(f'f(x) = {function_str}')
            plt.title('Function Visualization')
            plt.grid(True)

            mr.Pyplot(plt.gcf())
            plt.close()
        except Exception as e:
            logging.error(f"Error in visualizing function: {e}")
            mr.Markdown(f"**Error:** {e}")
    elif operation_value == "Integrate Symbolically":
        try:
            expression_str = extract_expression(question_input.value)
            x = sp.symbols('x')
            expr = safe_parse(expression_str)
            integral = sp.integrate(expr, x)
            steps = f"∫ {expression_str} dx = {integral}"
            result = str(integral)
            mr.Markdown(f"**Result:** {result}")
            mr.Markdown(f"**Steps:**\n```\n{steps}\n```")
        except Exception as e:
            logging.error(f"Error in symbolic integration: {e}")
            mr.Markdown(f"**Error:** {e}")
    elif operation_value == "Integrate Numerically":
        try:
            expression_str = extract_expression(question_input.value)
            x = sp.symbols('x')
            expr = safe_parse(expression_str)
            func = sp.lambdify(x, expr, 'numpy')
            lower_limit, upper_limit = extract_limits(question_input.value)
            result, error = integrate.quad(func, lower_limit, upper_limit)
            mr.Markdown(f"**Integral:** {result}")
            mr.Markdown(f"**Error Estimate:** {error}")
        except Exception as e:
            logging.error(f"Error in numerical integration: {e}")
            mr.Markdown(f"**Error:** {e}")
    elif operation_value == "Definite Integral":
        try:
            expression_str = extract_expression(question_input.value)
            lower_limit, upper_limit = extract_limits(question_input.value)
            x = sp.symbols('x')
            expr = safe_parse(expression_str)
            integral_result = sp.integrate(expr, (x, lower_limit, upper_limit))
            indefinite_integral = sp.integrate(expr, x)
            steps = f"∫ {expression_str} dx = {indefinite_integral}"
            result = str(integral_result)
            mr.Markdown(f"**Definite Integral from {lower_limit} to {upper_limit}:** {result}")
            mr.Markdown(f"**Steps:**\n```\n{steps}\n```")
        except Exception as e:
            logging.error(f"Error in definite integration: {e}")
            mr.Markdown(f"**Error:** {e}")
    elif operation_value == "Differentiate":
        try:
            function_str = extract_function_to_differentiate(question_input.value)
            if not function_str:
                mr.Markdown("**Error:** Could not extract function to differentiate.")
                raise ValueError("Function extraction failed.")
            x = sp.symbols('x')
            expr = safe_parse(function_str)
            derivative = sp.diff(expr, x)
            steps = f"d/dx {function_str} = {derivative}"
            result = str(derivative)
            mr.Markdown(f"**Result:** {result}")
            mr.Markdown(f"**Steps:**\n```\n{steps}\n```")
        except Exception as e:
            logging.error(f"Error in differentiation: {e}")
            mr.Markdown(f"**Error:** {e}")
    elif operation_value == "Solve Linear System":
        mr.Markdown("**Error:** Solving linear systems from natural language input is not implemented.")
        # Implement parsing for linear systems if needed
# Out:
# mercury.Text
# **Result:** cos(x)
# **Steps:**
# ```
# d/dx sin(x) = cos(x)
# ```
